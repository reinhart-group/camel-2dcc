# %% [markdown]
# # 3D surface test
#
# A real AFM scan as a rotatable 3D surface. This output was saved by the build; it should rotate on a phone with no Google sign-in and no runtime, as long as the device can reach the Plotly CDN.

# %%
from camel_data.classroom import load_scan, surface_3d
surface_3d(load_scan("triangle_pyramids"), exaggeration=3).show()
# Out:
# <div style="height:430px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from camel_data.classroom import load_scan, surface_3d
surface_3d(load_scan("wse2_triangles"), exaggeration=3).show()
# Out:
# <div style="height:430px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
