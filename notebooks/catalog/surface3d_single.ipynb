# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/summit-menu/notebooks/catalog/surface3d_single.ipynb)
#
# # One surface, nothing else
#
# The control. A single Plotly 3D scene, drawn immediately, alone in the notebook. This is the arrangement already shown to work. If this draws and the three-scan viewer does not, the limit is stricter than one live context per page.

# %%
surface_3d(SCANS["triangle_pyramids"], exaggeration=3).show()
# Out:
# <div id="camel-plot-b6b19119207d" style="height:420px;width:100%;"></div>
# <script>(function(){
# ...
