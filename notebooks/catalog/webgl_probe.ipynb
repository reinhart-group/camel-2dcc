# %% [markdown]
# # Five ways to draw the same 6x6 bump
#
# WebGL 2.0 is available on your machine with 40+ contexts, so the device is not the limit, and the colour bar proves Plotly is running. What is left is that the 3D canvas is being created at zero size, inside an output frame that only gets its real size a moment later. The SVG colour bar reflows; a WebGL scene does not.
#
# Each probe below changes one thing. **Please say which ones show a surface.**

# %% [markdown]
# ## 1. Fixed pixel size, not a percentage
#
# The scene is given a definite width and height up front, so it is never created at zero size.

# %%
# saved output below
# Out:
# <div id="p1" style="height:340px;width:100%;"></div>
# <script>(function(){
# ...

# %% [markdown]
# ## 2. Percentage size, then forced to resize after a moment
#
# What we ship now, plus a resize once the frame has settled.

# %%
# saved output below
# Out:
# <div id="p2" style="height:340px;width:100%;"></div>
# <script>(function(){
# ...

# %% [markdown]
# ## 3. Percentage size, resized whenever the frame changes size
#
# Same, but watching for the resize instead of guessing when it happens.

# %%
# saved output below
# Out:
# <div id="p3" style="height:340px;width:100%;"></div>
# <script>(function(){
# ...

# %% [markdown]
# ## 4. A 3D scatter instead of a surface
#
# Same 3D machinery, different trace. Separates a surface bug from a 3D bug.

# %%
# saved output below
# Out:
# <div id="p4" style="height:340px;width:100%;"></div>
# <script>(function(){
# ...

# %% [markdown]
# ## 5. An ordinary 2D scatter
#
# The baseline. This uses no WebGL at all and should certainly draw.

# %%
# saved output below
# Out:
# <div id="p5" style="height:300px;width:100%;"></div>
# <script>(function(){
# ...
