# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/summit-menu/notebooks/catalog/webgl_probe.ipynb)
#
# # Can this browser render into the buffers Plotly 3D needs?
#
# WebGL 2.0 is available on your machine and the colour bar draws, so Plotly runs and the GPU works. The remaining suspect is narrower: Plotly's 3D stack renders into **off-screen framebuffers backed by floating-point textures**, and WebKit has a long history of reporting those as unsupported even where plain WebGL is fine. If that is it, the 3D scene silently produces nothing while every 2D element is unaffected — which is exactly what you see.
#
# This is plain JavaScript, no libraries. **Please paste back everything it prints.** The line that matters most is `float texture FBO`.

# %%
# what this browser can render into
# Out:
# <div id="camel-gl2" style="font:13px/1.6 ui-monospace,monospace;padding:12px;border:1px solid #ccc;border-radius:8px;white-space:pre-wrap"></div>
# <script>(function(){
#   var L = [], el = document.getElementById("camel-gl2");
#   function say(k, v){ L.push(k + ": " + v); }
#   var c = document.createElement("canvas"); c.width = c.height = 64;
#   var gl2 = c.getContext("webgl2"), gl = gl2 || c.getContext("webgl");
#   if (!gl) { el.textContent = "no WebGL at all"; return; }
#   say("context", gl2 ? "webgl2" : "webgl1");
#
#   // Plotly's 3D stack renders into off-screen framebuffers backed by float textures.
#   // If these come back incomplete, gl3d draws nothing while the SVG layer is unaffected.
#   function tryFBO(label, internalFmt, fmt, type, exts){
#     (exts || []).forEach(function(e){ gl.getExtension(e); });
#     var t = gl.createTexture();
#     gl.bindTexture(gl.TEXTURE_2D, t);
#     gl.texParameteri(gl.TEXTURE_2D, gl.TEXTURE_MIN_FILTER, gl.NEAREST);
# ...
