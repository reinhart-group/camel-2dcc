# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/summit-menu/notebooks/catalog/webgl_probe_v2.ipynb)
#
# # The same question, asked correctly this time
#
# The previous probe had two bugs of mine, so two of its lines were about my code rather than your browser.
#
# It asked for a **WebGL 2** context and then listed WebGL 1 extensions. Those are *supposed* to be absent under WebGL 2, because the features are built into the core — so every `NO` in that list was expected and meaningless. It also built its float texture with an unsized `RGBA` format, which is never renderable under WebGL 2, so `INCOMPLETE_ATTACHMENT` was my error, not a limitation. `EXT_color_buffer_float: yes` in fact suggests float rendering works fine.
#
# This version asks both contexts separately, and asks each one the question it can actually answer. The **WebGL 1** block is the one that matters: Plotly's 3D code is built on an older stack that requires those extensions.
#
# **Please paste back everything it prints.** The `VERDICT` line is the summary.

# %%
# corrected capability probe
# Out:
# <div id="camel-gl3" style="font:13px/1.6 ui-monospace,monospace;padding:12px;border:1px solid #ccc;border-radius:8px;white-space:pre-wrap"></div>
# <script>(function(){
#   var L = [], el = document.getElementById("camel-gl3");
#   function say(s){ L.push(s); }
#
#   var STATUS = {};
#   function statusName(gl, st){
#     if (!STATUS.done){
#       STATUS[gl.FRAMEBUFFER_COMPLETE] = "COMPLETE";
#       STATUS[gl.FRAMEBUFFER_INCOMPLETE_ATTACHMENT] = "INCOMPLETE_ATTACHMENT";
#       STATUS[gl.FRAMEBUFFER_UNSUPPORTED] = "UNSUPPORTED";
#       STATUS.done = 1;
#     }
#     return STATUS[st] || ("0x" + st.toString(16));
#   }
#
#   function fbo(gl, label, internalFmt, fmt, type){
#     var t = gl.createTexture();
#     gl.bindTexture(gl.TEXTURE_2D, t);
#     gl.texParameteri(gl.TEXTURE_2D, gl.TEXTURE_MIN_FILTER, gl.NEAREST);
#     gl.texParameteri(gl.TEXTURE_2D, gl.TEXTURE_MAG_FILTER, gl.NEAREST);
#     try { gl.texImage2D(gl.TEXTURE_2D, 0, internalFmt, 64, 64, 0, fmt, type, null); }
# ...
