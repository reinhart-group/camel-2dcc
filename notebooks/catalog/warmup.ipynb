# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/summit-menu/notebooks/catalog/warmup.ipynb)
#
# # Round 0 - warm up: notice and wonder
#
# Every item below already works: tap, drag, and choose. Nothing needs to be signed in to or run. Tell us which item IDs you want and we will refine those.
#
# - **W-01** What do you see in this picture? — One microscope height map, no labels yet. Notice, wonder, then reveal what it is.
# - **W-02** What is this pile of numbers? — A histogram with no labels yet. Notice the shape, then reveal what was measured.
# - **W-03** What happened during this recipe? — A temperature trace from a real growth recipe, with no labels yet. Notice, wonder, then reveal what was cooking.
# - **W-04** What is happening to this material as it warms up? — A resistance-vs-temperature curve with no labels yet. Notice, wonder, then reveal what was measured.
# - **W-05** How rough are these films, really? — A histogram of roughness for every measured sample. Change the number of bins and toggle the mean and median.
# - **W-06** Does roughness look different for one material? — The same roughness histogram, but pick a single material to look at.
# - **W-07** How big are the islands on one wafer? — A histogram of measured island (grain) areas from one real AFM scan.
# - **W-08** How long do these growths take? — A histogram of total recorded growth time across every sample with a time on record.

# %% [markdown]
# ## W-01 — What do you see in this picture?
#
# One microscope height map, no labels yet. Notice, wonder, then reveal what it is.
#
# *Grades 6-12. Data: one AFM height map, 2DCC gallery.*

# %%
# W-01: the working version is saved below.
# Out:
# <W-01 widget>

# %% [markdown]
# ## W-02 — What is this pile of numbers?
#
# A histogram with no labels yet. Notice the shape, then reveal what was measured.
#
# *Grades 6-12. Data: 894 AFM roughness measurements, 2DCC LiST records.*

# %%
# W-02: the working version is saved below.
# Out:
# <W-02 widget>

# %% [markdown]
# ## W-03 — What happened during this recipe?
#
# A temperature trace from a real growth recipe, with no labels yet. Notice, wonder, then reveal what was cooking.
#
# *Grades 6-12. Data: one growth recipe, 2DCC LiST records, sample 17403.*

# %%
# W-03: the working version is saved below.
# Out:
# <W-03 widget>

# %% [markdown]
# ## W-04 — What is happening to this material as it warms up?
#
# A resistance-vs-temperature curve with no labels yet. Notice, wonder, then reveal what was measured.
#
# *Grades 6-12. Data: 183 resistance measurements on one FeSe sample, 2DCC extras.*

# %%
# W-04: the working version is saved below.
# Out:
# <W-04 widget>

# %% [markdown]
# ## W-05 — How rough are these films, really?
#
# A histogram of roughness for every measured sample. Change the number of bins and toggle the mean and median.
#
# *Grades 6-12. Data: 894 samples with AFM roughness, 2DCC LiST records.*

# %%
# W-05: the working version is saved below.
# Out:
# <W-05 widget>

# %% [markdown]
# ## W-06 — Does roughness look different for one material?
#
# The same roughness histogram, but pick a single material to look at.
#
# *Grades 6-12. Data: 894 samples with AFM roughness, 2DCC LiST records.*

# %%
# W-06: the working version is saved below.
# Out:
# <W-06 widget>

# %% [markdown]
# ## W-07 — How big are the islands on one wafer?
#
# A histogram of measured island (grain) areas from one real AFM scan.
#
# *Grades 6-12. Data: 501 detected grains, one WSe2 scan, sample 17458 (2DCC grains dataset).*

# %%
# W-07: the working version is saved below.
# Out:
# <W-07 widget>

# %% [markdown]
# ## W-08 — How long do these growths take?
#
# A histogram of total recorded growth time across every sample with a time on record.
#
# *Grades 6-12. Data: 775 samples with a recorded growth time, 2DCC LiST records.*

# %%
# W-08: the working version is saved below.
# Out:
# <W-08 widget>
