# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/summit-menu/notebooks/catalog/plotly_trace.ipynb)
#
# # What is actually going wrong
#
# Your browser supports everything Plotly 3D needs — WebGL 1 with every required extension, and every framebuffer complete in both contexts. The only failure in that report was a bug in my own probe, which I left in as a control.
#
# I have proposed four causes tonight and every one was wrong, because I kept reasoning about the failure instead of reading it. This page does the opposite: it captures every error, warning and rejection Plotly produces, then reports whether the 3D engine was created at all, how many canvases exist, their real pixel sizes, and whether their WebGL contexts are alive.
#
# **Paste back the whole log box.** Whatever it says will name the cause rather than suggest another theory.

# %%
# instrumented draw: log first, conclude second
# Out:
# <div id="camel-log" style="font:12px/1.5 ui-monospace,monospace;padding:10px;border:1px solid #ccc;border-radius:8px;white-space:pre-wrap;margin-bottom:10px"></div>
# <div id="camel-plot" style="height:320px;width:100%;border:1px dashed #bbb"></div>
# <script>(function(){
#   var L = [], log = document.getElementById("camel-log");
#   function say(s){ L.push(s); log.textContent = L.join("\n"); }
#
#   // Capture everything that goes wrong, instead of guessing at what did.
#   window.addEventListener("error", function(e){
#     say("window error: " + e.message + (e.filename ? "  @ " + e.filename + ":" + e.lineno : ""));
#   });
#   window.addEventListener("unhandledrejection", function(e){
#     say("unhandled rejection: " + (e.reason && (e.reason.stack || e.reason.message) || e.reason));
#   });
#   var realErr = console.error;
#   console.error = function(){ say("console.error: " + Array.prototype.join.call(arguments, " ")); realErr.apply(console, arguments); };
# ...
