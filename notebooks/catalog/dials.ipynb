# %% [markdown]
# # Round 4 - turn the dials
#
# Every item below already works: tap, drag, and choose. Nothing needs to be signed in to or run. Tell us which item IDs you want and we will refine those.
#
# - **D-01** Turn all three complexity dials — The full structural, provenance, and statistical dials over the sample table and a growth-time-versus-roughness plot: the data never change, only what you meet first.
# - **D-02** A simplified two-dial version — Only the structural and statistical dials; provenance is fixed at 'resolved' so a beginner meets one fewer decision at once.
# - **D-05** What a grades 6-8 classroom would see — The dials start with the messier, surfaced spellings but still filtered noise.
# - **D-06** What a grades 9-12 classroom would see — The dials start at full complexity: every variable, surfaced spellings, and every scan size and roughness value, noise and all.

# %% [markdown]
# ## D-01 — Turn all three complexity dials
#
# The full structural, provenance, and statistical dials over the sample table and a growth-time-versus-roughness plot: the data never change, only what you meet first.
#
# *Grades 6-12. Data: 1,005 samples, 2DCC LiST records, every dial position shown.*

# %%
# D-01: the working version is saved below.
# Out:
# <D-01 widget>

# %% [markdown]
# ## D-02 — A simplified two-dial version
#
# Only the structural and statistical dials; provenance is fixed at 'resolved' so a beginner meets one fewer decision at once.
#
# *Grades 6-12. Data: 1,005 samples, 2DCC LiST records, resolved provenance held fixed.*

# %%
# D-02: the working version is saved below.
# Out:
# <D-02 widget>

# %% [markdown]
# ## D-05 — What a grades 6-8 classroom would see
#
# The dials start with the messier, surfaced spellings but still filtered noise.
#
# *Grades 6-8. Data: 1,005 samples, 2DCC LiST records, 6-8 starting position.*

# %%
# D-05: the working version is saved below.
# Out:
# <D-05 widget>

# %% [markdown]
# ## D-06 — What a grades 9-12 classroom would see
#
# The dials start at full complexity: every variable, surfaced spellings, and every scan size and roughness value, noise and all.
#
# *Grades 9-12. Data: 1,005 samples, 2DCC LiST records, 9-12 starting position.*

# %%
# D-06: the working version is saved below.
# Out:
# <D-06 widget>
