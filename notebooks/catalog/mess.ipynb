# %% [markdown]
# # Round 2 - find the mess
#
# Every item below already works: tap, drag, and choose. Nothing needs to be signed in to or run. Tell us which item IDs you want and we will refine those.
#
# - **M-01** Does the growth method change how rough the film is? — Box plots of measured roughness by growth method, material, or substrate, with medians and the gap between the two biggest groups.
# - **M-02** If you need both time and roughness recorded, who survives — by growth method? — Toggle two requirements and watch how many rows survive, overall and for each growth method.
# - **M-03** If you need both time and roughness recorded, who survives — by material? — The same two requirements, broken down by material instead of growth method.
# - **M-04** If you need both time and roughness recorded, who survives — by year? — The same two requirements, broken down by the year the sample was grown.
# - **M-05** Sort the messy material list — 22 spellings were typed by hand into one “material” field. You don't need to know any chemistry — every spelling gets a plain-English gloss. Sort each by what kind of labeling problem it has, then see where an automatic cleanup script disagrees with you.
# - **M-07** One sample, two materials — which one counts? — Some rows list two materials separated by a semicolon. Sort each one; then see which half a cleanup script keeps.
# - **M-08** Which material's film measures roughest — and does that hold up? — Compare roughness across six materials, then lock the comparison to one scan size and watch the sample count (n) for each material, not just the medians.
# - **M-09** Does growth method change roughness, even after controlling for scan size? — Compare roughness between two ways of growing these crystals, then check the gap at specific scan sizes to see whether it survives.
# - **M-10** Does scan size alone change the roughness number, even for one material? — Every sample here is the same material, WSe2. Step through scan sizes and watch the distribution, its median, and its sample count (n) move together.
# - **M-11** Which extreme roughness readings would you trust? — A sortable table of the roughest measured samples. Mark each keep, fix, or remove.
# - **M-12** Which scans stopped before they finished? — A sortable table of scans where the recorded lines are fewer than the pixels across — meaning the scan stopped early. Mark each keep, fix, or remove and watch the chart of lines-recorded move.
# - **M-13** All the odd-looking rows in one table — Every sample flagged for extreme roughness or an early-stopped scan, filterable by reason. Mark each keep, fix, or remove.

# %% [markdown]
# ## M-01 — Does the growth method change how rough the film is?
#
# Box plots of measured roughness by growth method, material, or substrate, with medians and the gap between the two biggest groups.
#
# *Grades 6-12. Data: 1,005 samples with AFM roughness, 2DCC LiST records.*

# %%
# M-01: the working version is saved below.
# Out:
# <M-01 widget>

# %% [markdown]
# ## M-02 — If you need both time and roughness recorded, who survives — by growth method?
#
# Toggle two requirements and watch how many rows survive, overall and for each growth method.
#
# *Grades 6-12. Data: 1,005 samples, 2DCC LiST records (uncleaned).*

# %%
# M-02: the working version is saved below.
# Out:
# <M-02 widget>

# %% [markdown]
# ## M-03 — If you need both time and roughness recorded, who survives — by material?
#
# The same two requirements, broken down by material instead of growth method.
#
# *Grades 6-12. Data: 1,000 cleaned samples, 2DCC LiST records.*

# %%
# M-03: the working version is saved below.
# Out:
# <M-03 widget>

# %% [markdown]
# ## M-04 — If you need both time and roughness recorded, who survives — by year?
#
# The same two requirements, broken down by the year the sample was grown.
#
# *Grades 6-12. Data: 1,000 cleaned samples, 2DCC LiST records.*

# %%
# M-04: the working version is saved below.
# Out:
# <M-04 widget>

# %% [markdown]
# ## M-05 — Sort the messy material list
#
# 22 spellings were typed by hand into one “material” field. You don't need to know any chemistry — every spelling gets a plain-English gloss. Sort each by what kind of labeling problem it has, then see where an automatic cleanup script disagrees with you.
#
# *Grades 6-12. Data: 951 of 1,005 samples, raw “material” text field, 2DCC LiST records.*

# %%
# M-05: the working version is saved below.
# Out:
# <M-05 widget>

# %% [markdown]
# ## M-07 — One sample, two materials — which one counts?
#
# Some rows list two materials separated by a semicolon. Sort each one; then see which half a cleanup script keeps.
#
# *Grades 6-12. Data: 39 of 1,005 samples, raw “material” text field, 2DCC LiST records.*

# %%
# M-07: the working version is saved below.
# Out:
# <M-07 widget>

# %% [markdown]
# ## M-08 — Which material's film measures roughest — and does that hold up?
#
# Compare roughness across six materials, then lock the comparison to one scan size and watch the sample count (n) for each material, not just the medians.
#
# *Grades 6-12. Data: samples with AFM roughness, restricted to the six most-measured materials.*

# %%
# M-08: the working version is saved below.
# Out:
# <M-08 widget>

# %% [markdown]
# ## M-09 — Does growth method change roughness, even after controlling for scan size?
#
# Compare roughness between two ways of growing these crystals, then check the gap at specific scan sizes to see whether it survives.
#
# *Grades 6-12. Data: samples with AFM roughness, both growth methods.*

# %%
# M-09: the working version is saved below.
# Out:
# <M-09 widget>

# %% [markdown]
# ## M-10 — Does scan size alone change the roughness number, even for one material?
#
# Every sample here is the same material, WSe2. Step through scan sizes and watch the distribution, its median, and its sample count (n) move together.
#
# *Grades 6-12. Data: WSe2 samples with AFM roughness, 2DCC LiST records.*

# %%
# M-10: the working version is saved below.
# Out:
# <M-10 widget>

# %% [markdown]
# ## M-11 — Which extreme roughness readings would you trust?
#
# A sortable table of the roughest measured samples. Mark each keep, fix, or remove.
#
# *Grades 6-12. Data: 66 of 1,000 cleaned samples, roughness 5 nm or higher.*

# %%
# M-11: the working version is saved below.
# Out:
# <M-11 widget>

# %% [markdown]
# ## M-12 — Which scans stopped before they finished?
#
# A sortable table of scans where the recorded lines are fewer than the pixels across — meaning the scan stopped early. Mark each keep, fix, or remove and watch the chart of lines-recorded move.
#
# *Grades 6-12. Data: 110 of 1,000 cleaned samples, scan lines fewer than pixels.*

# %%
# M-12: the working version is saved below.
# Out:
# <M-12 widget>

# %% [markdown]
# ## M-13 — All the odd-looking rows in one table
#
# Every sample flagged for extreme roughness or an early-stopped scan, filterable by reason. Mark each keep, fix, or remove.
#
# *Grades 6-12. Data: 174 of 1,000 cleaned samples, flagged for one or both reasons.*

# %%
# M-13: the working version is saved below.
# Out:
# <M-13 widget>
