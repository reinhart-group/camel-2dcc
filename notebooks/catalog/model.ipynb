# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/summit-menu/notebooks/catalog/model.ipynb)
#
# # Round 3 - model it
#
# Every item below already works: tap, drag, and choose. Nothing needs to be signed in to or run. Tell us which item IDs you want and we will refine those.
#
# - **G-01** Does growing a film longer change how rough it is? — Scatter plot of roughness against growth time, with a least-squares line, its slope and R-squared, and a count of how many samples could be drawn.
# - **G-02** Growth time and roughness, coloured by material — Same growth-time-versus-roughness plot, with a toggle to colour each point by the material grown, so a learner can see whether one line fits every material.
# - **G-03** Does growth temperature change how rough the film is? — Scatter plot of roughness against growth temperature, with a least-squares line and a count of how many of the 1,005 samples had both values recorded.
# - **G-04** Growth temperature and roughness, coloured by material — Roughness against growth temperature, with a toggle to colour points by material.
# - **G-05** Does chamber pressure change how rough the film is? — Roughness against growth pressure, with a least-squares line, slope, and R-squared.
# - **G-06** How much does a sample mean bounce around? — Draw random samples of n grains from a real wafer and watch the sample mean area move around the population mean, one histogram bar at a time.
# - **G-07** A convenience sample: only the center of the wafer — The same sampling studio, restricted by default to the wafer's center spot, to show what a convenience sample can miss.
# - **G-08** A convenience sample: only the wafer's edge — The same sampling studio, restricted by default to the wafer's edge spot.
# - **G-09** Read a real MOCVD growth recipe — Temperature versus elapsed time for one real growth recipe, step by step, with each step's duration and its rate of temperature change from the step before.
# - **G-10** Read a real hybrid MBE growth recipe — The same kind of temperature-versus-time reading, for a longer 13-step hybrid MBE recipe.
# - **G-11** Compare an MOCVD recipe to a hybrid MBE recipe — Both real recipes plotted on the same temperature-versus-time axes, so a learner can see how differently the two growth methods run.
# - **G-12** Read heights off terraced triangle crystals — A real height map of a crystal surface, with a draggable line whose height profile plots below, so a learner can read off the height of each terrace.
# - **G-13** Read heights off stacked triangle crystals — A real height map of stacked triangular crystals, with a draggable profile line.
# - **G-14** Where does the resistance drop to (almost) zero? — A real resistance-versus-temperature sweep, with a draggable threshold to estimate the temperature where resistance falls away.
# - **G-15** Check a claim: does growth time predict roughness? — Pick a claim about the data, see the evidence for and against it (including how much data is missing), then rewrite the claim with a limitation.
# - **G-16** Check a claim: is MOCVD smoother than hybrid MBE? — The same claim-checking tool, opened on the growth-method claim first.

# %% [markdown]
# ## G-01 — Does growing a film longer change how rough it is?
#
# Scatter plot of roughness against growth time, with a least-squares line, its slope and R-squared, and a count of how many samples could be drawn.
#
# *Grades 6-12. Data: 1,005 samples' recipe settings joined to their AFM roughness, 2DCC LiST records.*

# %%
# G-01: the working version is saved below.
# Out:
# <G-01 widget>

# %% [markdown]
# ## G-02 — Growth time and roughness, coloured by material
#
# Same growth-time-versus-roughness plot, with a toggle to colour each point by the material grown, so a learner can see whether one line fits every material.
#
# *Grades 6-12. Data: 1,005 samples' recipe settings joined to their AFM roughness, 2DCC LiST records.*

# %%
# G-02: the working version is saved below.
# Out:
# <G-02 widget>

# %% [markdown]
# ## G-03 — Does growth temperature change how rough the film is?
#
# Scatter plot of roughness against growth temperature, with a least-squares line and a count of how many of the 1,005 samples had both values recorded.
#
# *Grades 6-12. Data: 1,005 samples' recipe settings joined to their AFM roughness, 2DCC LiST records.*

# %%
# G-03: the working version is saved below.
# Out:
# <G-03 widget>

# %% [markdown]
# ## G-04 — Growth temperature and roughness, coloured by material
#
# Roughness against growth temperature, with a toggle to colour points by material.
#
# *Grades 6-12. Data: 1,005 samples' recipe settings joined to their AFM roughness, 2DCC LiST records.*

# %%
# G-04: the working version is saved below.
# Out:
# <G-04 widget>

# %% [markdown]
# ## G-05 — Does chamber pressure change how rough the film is?
#
# Roughness against growth pressure, with a least-squares line, slope, and R-squared.
#
# *Grades 9-12. Data: 1,005 samples' recipe settings joined to their AFM roughness, 2DCC LiST records.*

# %%
# G-05: the working version is saved below.
# Out:
# <G-05 widget>

# %% [markdown]
# ## G-06 — How much does a sample mean bounce around?
#
# Draw random samples of n grains from a real wafer and watch the sample mean area move around the population mean, one histogram bar at a time.
#
# *Grades 6-12. Data: 501 real, non-touching single grains measured across 3 AFM scans on one WSe2 wafer (sample 17458), 2DCC LiST records.*

# %%
# G-06: the working version is saved below.
# Out:
# <G-06 widget>

# %% [markdown]
# ## G-07 — A convenience sample: only the center of the wafer
#
# The same sampling studio, restricted by default to the wafer's center spot, to show what a convenience sample can miss.
#
# *Grades 6-12. Data: 501 real, non-touching single grains measured across 3 AFM scans on one WSe2 wafer (sample 17458), 2DCC LiST records.*

# %%
# G-07: the working version is saved below.
# Out:
# <G-07 widget>

# %% [markdown]
# ## G-08 — A convenience sample: only the wafer's edge
#
# The same sampling studio, restricted by default to the wafer's edge spot.
#
# *Grades 6-12. Data: 501 real, non-touching single grains measured across 3 AFM scans on one WSe2 wafer (sample 17458), 2DCC LiST records.*

# %%
# G-08: the working version is saved below.
# Out:
# <G-08 widget>

# %% [markdown]
# ## G-09 — Read a real MOCVD growth recipe
#
# Temperature versus elapsed time for one real growth recipe, step by step, with each step's duration and its rate of temperature change from the step before.
#
# *Grades 6-12. Data: one recipe (11 steps) from growth_recipes.csv, sample 28363, 2DCC LiST records.*

# %%
# G-09: the working version is saved below.
# Out:
# <G-09 widget>

# %% [markdown]
# ## G-10 — Read a real hybrid MBE growth recipe
#
# The same kind of temperature-versus-time reading, for a longer 13-step hybrid MBE recipe.
#
# *Grades 6-12. Data: one recipe (13 steps) from growth_recipes.csv, sample 69173, 2DCC LiST records.*

# %%
# G-10: the working version is saved below.
# Out:
# <G-10 widget>

# %% [markdown]
# ## G-11 — Compare an MOCVD recipe to a hybrid MBE recipe
#
# Both real recipes plotted on the same temperature-versus-time axes, so a learner can see how differently the two growth methods run.
#
# *Grades 6-12. Data: two recipes from growth_recipes.csv, samples 17458 and 69173, 2DCC LiST records.*

# %%
# G-11: the working version is saved below.
# Out:
# <G-11 widget>

# %% [markdown]
# ## G-12 — Read heights off terraced triangle crystals
#
# A real height map of a crystal surface, with a draggable line whose height profile plots below, so a learner can read off the height of each terrace.
#
# *Grades 6-12. Data: one AFM scan, 2 µm across, sample 17853 (InSe), 2DCC gallery.*

# %%
# G-12: the working version is saved below.
# Out:
# <G-12 widget>

# %% [markdown]
# ## G-13 — Read heights off stacked triangle crystals
#
# A real height map of stacked triangular crystals, with a draggable profile line.
#
# *Grades 6-12. Data: one AFM scan, 1 µm across, sample 50210 (Bi2Se3), 2DCC gallery.*

# %%
# G-13: the working version is saved below.
# Out:
# <G-13 widget>

# %% [markdown]
# ## G-14 — Where does the resistance drop to (almost) zero?
#
# A real resistance-versus-temperature sweep, with a draggable threshold to estimate the temperature where resistance falls away.
#
# *Grades 9-12. Data: 183 real resistance measurements, 2 K to 300 K, sample 20201 (FeSe), 2DCC extras/transport_fese.csv.*

# %%
# G-14: the working version is saved below.
# Out:
# <G-14 widget>

# %% [markdown]
# ## G-15 — Check a claim: does growth time predict roughness?
#
# Pick a claim about the data, see the evidence for and against it (including how much data is missing), then rewrite the claim with a limitation.
#
# *Grades 9-12. Data: 1,005 samples' recipe settings joined to their AFM roughness, 2DCC LiST records.*

# %%
# G-15: the working version is saved below.
# Out:
# <G-15 widget>

# %% [markdown]
# ## G-16 — Check a claim: is MOCVD smoother than hybrid MBE?
#
# The same claim-checking tool, opened on the growth-method claim first.
#
# *Grades 9-12. Data: 1,005 samples' recipe settings joined to their AFM roughness, 2DCC LiST records.*

# %%
# G-16: the working version is saved below.
# Out:
# <G-16 widget>
