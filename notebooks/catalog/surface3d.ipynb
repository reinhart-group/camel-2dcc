# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/summit-menu/notebooks/catalog/surface3d.ipynb)
#
# # Real microscope scans you can spin
#
# Pick a scan, then tap **spin it**. Drag to rotate, pinch to zoom.
#
# All three share one viewer on purpose. Safari here cannot keep more than one live 3D view alive on a page — with three at once, every one of them goes blank — and Colab puts each cell's output in its own frame, so separate cells cannot hand the 3D view between them. One output, one viewer, one scan at a time is the arrangement that works.
#
# The still pictures are real renders of the same measurements, so the page is never empty: not if you never tap, not if the 3D library cannot be reached, not if the browser reclaims the view.

# %%
# One viewer, several scans. Choosing a scan tears the previous 3D view down first,
# so only one WebGL context is ever alive.
for name in ["triangle_pyramids", "wse2_triangles", "superconductor_blocks"]:
    surface_3d(SCANS[name], exaggeration=3)
# Out:
# <div style="font-family:-apple-system,system-ui,sans-serif">
#   <div><button data-i="0" class="camel-gal-13d7899eb3-pick" style="padding:9px 13px;margin:3px;font-size:14px;border-radius:7px;border:1px solid #2b6cb0;background:#fff;color:#2b6cb0">Triangle pyramids</button><button data-i="1" class="camel-gal-13d7899eb3-pick" style="padding:9px 13px;margin:3px;font-size:14px;border-radius:7px;border:1px solid #2b6cb0;background:#fff;color:#2b6cb0">Triangles, with a glitch</button><button data-i="2" class="camel-gal-13d7899eb3-pick" style="padding:9px 13px;margin:3px;font-size:14px;border-radius:7px;border:1px solid #2b6cb0;background:#fff;color:#2b6cb0">Superconductor city blocks</button></div>
#   <p id="camel-gal-13d7899eb3-cap" style="font-size:14px;color:#374151;margin:8px 2px"></p>
#   <div style="position:relative;height:420px;width:100%">
#     <img id="camel-gal-13d7899eb3-img" style="width:100%;height:100%;object-fit:contain" alt="3D view">
# ...
