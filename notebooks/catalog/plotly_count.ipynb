# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/summit-menu/notebooks/catalog/plotly_count.ipynb)
#
# # Does a second 3D plot kill the first?
#
# On a page with one surface, it drew perfectly: canvas the right size, context alive, engine created, no errors. On a page with five, none drew. In the two-surface notebook, the second drew and the first did not.
#
# That is the signature of a **WebGL context limit**: the browser holds only so many live 3D canvases and discards the oldest, so the newest plot wins. My earlier probe counted 40+ bare canvas contexts, but a bare canvas is far cheaper than a Plotly scene, and each Colab output sits in its own frame.
#
# Three identical surfaces below. Each reports its own context state every three seconds and shouts if it is taken away.
#
# **Which of the three draw, and what do the little grey status lines say?**

# %% [markdown]
# ## Surface 1

# %%
# surface 1
# Out:
# <div id="log1" style="font:12px ui-monospace,monospace;padding:6px;color:#444"></div>
# <div id="plot1" style="height:300px;width:100%;border:1px dashed #bbb"></div>
# <script>(function(){
#   var log = document.getElementById("log1"), el = document.getElementById("plot1");
#   var msgs = [];
#   function say(s){ msgs.push(s); log.textContent = msgs.join(" | "); }
# ...

# %% [markdown]
# ## Surface 2

# %%
# surface 2
# Out:
# <div id="log2" style="font:12px ui-monospace,monospace;padding:6px;color:#444"></div>
# <div id="plot2" style="height:300px;width:100%;border:1px dashed #bbb"></div>
# <script>(function(){
#   var log = document.getElementById("log2"), el = document.getElementById("plot2");
#   var msgs = [];
#   function say(s){ msgs.push(s); log.textContent = msgs.join(" | "); }
# ...

# %% [markdown]
# ## Surface 3

# %%
# surface 3
# Out:
# <div id="log3" style="font:12px ui-monospace,monospace;padding:6px;color:#444"></div>
# <div id="plot3" style="height:300px;width:100%;border:1px dashed #bbb"></div>
# <script>(function(){
#   var log = document.getElementById("log3"), el = document.getElementById("plot3");
#   var msgs = [];
#   function say(s){ msgs.push(s); log.textContent = msgs.join(" | "); }
# ...
