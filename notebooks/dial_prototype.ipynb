# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reinhart-group/camel-2dcc/blob/dial-prototype/notebooks/dial_prototype.ipynb)

# %% [markdown]
# # Complexity dials, running in the page
#
# One real dataset from Penn State's 2D Crystal Consortium: 1,005 crystal samples, the settings
# each one was grown with, and how rough the finished film measured.
#
# The three dials below are the CAMEL complexity dials. They change **what you see first**, never
# the underlying records. Turn them and watch the row count, the missing values, and the graph
# change.
#
# This cell's output is saved in the notebook, so it works on a phone with no account and nothing
# running. Sign in and run the cells to see the Python that built it.

# %%
# @title Turn the dials { display-mode: "form" }
# (Run this cell only if you want to rebuild the widget. The saved version below already works.)
import json
import pathlib
import sys
import uuid

from IPython.display import HTML, display

ROOT = pathlib.Path.cwd()
if not (ROOT / "courseware").exists() and (ROOT.parent / "courseware").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "scripts"))

from build_dial_payload import build  # noqa: E402

rows = build()
payload = json.dumps(rows, separators=(",", ":"))
widget_id = "dials-" + uuid.uuid4().hex[:8]

js = (ROOT / "courseware/widgets/dials.js").read_text()
js = js.replace("__DATA__", payload).replace("__ID__", widget_id)
html = (ROOT / "courseware/widgets/dials.html").read_text()
html = html.replace("__ID__", widget_id).replace("__JS__", js)

print(f"{len(rows)} samples, {len(payload) / 1024:.0f} KB carried inside the page")
display(HTML(html))
# Out:
# 1005 samples, 234 KB carried inside the page
# <div id="dials-5f326380" class="camel-dials">
#   <style>
#     .camel-dials { font-family: -apple-system, system-ui, sans-serif; max-width: 560px; }
#     .camel-dials h3 { margin: 0 0 4px 0; font-size: 18px; }
#     .camel-dials p.q { margin: 0 0 10px 0; font-size: 14px; color: #333; }
#     .camel-dials .dials { display: flex; flex-wrap: wrap; gap: 10px; margin-bottom: 10px; }
#     .camel-dials .dial { flex: 1 1 160px; }
#     .camel-dials label { display: block; font-size: 13px; font-weight: 600; margin-bottom: 3px; }
#     .camel-dials select { width: 100%; font-size: 16px; padding: 9px; border: 1px solid #999;
#       border-radius: 6px; background: #fff; }
#     .camel-dials #count { font-size: 14px; margin: 8px 0; }
#     .camel-dials ul { font-size: 13px; color: #444; margin: 4px 0 10px 18px; padding: 0; }
#     .camel-dials table { border-collapse: collapse; font-size: 12px; width: 100%; }
#     .camel-dials th, .camel-dials td { border: 1px solid #ccc; padding: 3px 5px; text-align: left;
#       white-space: nowrap; }
#     .camel-dials th { background: #eef2f7; }
#     .camel-dials td.miss { background: #fdecea; }
#     .camel-dials .scroll { overflow-x: auto; }
#     .camel-dials .key { font-size: 12px; margin-top: 4px; }
#   </style>
#   <h3>Growing tiny crystals: turn the dials</h3>
#   <p class="q">Penn State's 2D Crystal Consortium grew these samples and measured how rough each
#   film came out. How do the recorded recipe settings relate to that measurement?</p>
#   <div class="dials">
#     <div class="dial">
#       <label for="st">Structural</label>
#       <select id="st">
#         <option value="few">few variables</option>
#         <option value="some" selected>some variables</option>
#         <option value="all">all variables</option>
#       </select>
#     </div>
#     <div class="dial">
#       <label for="pr">Provenance</label>
#       <select id="pr">
#         <option value="resolved" selected>resolved</option>
#         <option value="surfaced">surfaced</option>
#       </select>
#     </div>
#     <div class="dial">
#       <label for="sa">Statistical</label>
#       <select id="sa">
#         <option value="implicit" selected>noise implicit</option>
#         <option value="explicit">noise explicit</option>
#       </select>
#     </div>
#   </div>
#   <div id="count"></div>
#   <ul id="notes"></ul>
#   <div id="plot"></div>
#   <div class="scroll" id="tbl"></div>
#   <p class="q" style="margin-top:8px">The data never change. The dials only change what you meet
#   first.</p>
# </div>
# <script>(function(){
#   var DATA = [{"id":17207,"label":"MCV2-230113A-TM","mat":"MoS2","sub":"Al2O3","meth":"MOCVD","steps":37.0,"time":30.0,"temp":null,"press":100.0,"rough":0.375,"hrange":18.09,"scan":5.0,"pix":512.0,"lines":512.0,"date":"2023-01-13","doi":"10.26207/khwb-rr73"},{"id":17224,"label":"MCV2-230120B-TM","mat":"MoS2","sub":"Al2O3","meth":"MOCVD","steps":8.0,"time":40.0,"temp":null,"press":100.0,"rough":0.381,"hrange":15.01,"scan":5.0,"pix":512.0,"lines":512.0,"date":"2023-01-20","doi":"10.26207/khwb-rr73"},{"id":17391,"label":"MCV1-191016A-BH","mat":"Al2O3","sub":"Al2O3","meth":"MOCVD","steps":5.0,"time":null,"temp":null,"press":null,"rough":0.604,"hrange":16.54,"scan":3.34,"pix":512.0,"lines":256.0,"date":"2019-10-16","doi":"10.26207/f7b1-fs46"},{"id":17392,"label":"MCV1-191101A-BH","mat":"WSe2","sub":"Al2O3","meth":"MOCVD","steps":5.0,"time":null,"temp":null,"press":null,"rough":null,"hrange":null,"scan":null,"pix":null,"lines":null,"date":"2019-11-01","doi":"10.26207/f7b1-fs46"},{"id":17393,"label":"MCV1-191107A-HZ","mat":"WSe2","sub":"Al2O3","meth":"MOCVD","steps":8.0,"time":null,"temp":null,"press":null,"rough":1.012,"hrange":18.51,"scan":2.0,"pix":128.0,"lines":128.0,"date":"2019-11-07","doi":"10.26207/f7b1-fs46"},{"id":17394,"label":"MCV1-191111A-HZ","mat":"WSe2","sub":"Al2O3","meth":"MOCVD","steps":6.0,"time":null,"temp":null,"press":null,"rough":null,"hrange":null,"scan":null,"pix":null,"lines":null,"date":"2019-11-11","doi":"10.26207/f7b1-fs46"},{"id":17395,"label":"MCV1-191112A-HZ","mat":"WSe2","sub":"Al2O3","meth":"MOCVD","steps":9.0,"time":5.0,"temp":1000.0,"press":200.0,"rough":null,"hrange":null,"scan":null,"pix":null,"lines":null,"date":"2019-11-12","doi":"10.26207/f7b1-fs46"},{"id":17396,"label":"MCV1-191113A-HZ","mat":"WSe2","sub":"Al2O3","meth":"MOCVD","steps":9.0,"time":5.0,"temp":1000.0,"press":200.0,"rough":1.233,"hrange":10.67,"scan":2.0,"pix":512.0,"lines":512.0,"date":"2019-11-13","doi":"10.26207/f7b1-fs46"},{"id":17397,"label":"MCV1-191114A-HZ","mat":"WSe2","sub":"Al2O3","meth":"MOCVD","steps":8.0,"time":null,"temp":null,"press":null,"rough":0.826,"hrange":14.04,"scan":2.0,"pix":512.0,"lines":512.0,"date":"2019-11-14","doi":"10.26207/f7b1-fs46"},{"id":17398,"label":"MCV1-191114B-HZ","mat":"WSe2","sub":"Al2O3","meth":"MOCVD","steps":6.0,"time":null,"temp":null,"press":null,"rough":1.37,"hrange":29.8,"scan":1.0,"pix":512.0,"lines":512.0,"date":"2019-11-14","doi":"10.26207/f7b1-fs46"},{"id":17399,"label":"MCV1-191206A-HZ","mat":"WS2","sub":"Al2O3","meth":"MOCVD","steps":7.0,"time":null,"temp":null,"press":null,"rough":0.868,"hrange":21.47,"scan":5.0,"pix":512.0,"lines":512.0,"date":"2019-12-06","doi":"10.26207/f7b1-fs46"},{"id":17400,"label":"MCV1-191209A-HZ","mat":"WS2","sub":"Al2O3","meth":"MOCVD","steps":9.0,"time":null,"temp":null,"press":null,"rough":0.368,"hrange":6.56,"scan":5.0,"pix":512.0,"lines":512.0,"date":"2019-12-09","doi":"10.26207/f7b1-fs46"},{"id":17401,"label":"MCV1-191209B-HZ","mat":"WS2","sub":"Al2O3","meth":"MOCVD","steps":10.0,"time":5.0,"temp":1000.0,"press":50.0,"rough":0.646,"hrange":16.09,"scan":5.0,"pix":512.0,"lines":512.0,"date":"2019-12-09","doi":"10.26207/f7b1-fs46"},{"id":17402,"label":"MCV1-191210C-HZ","mat":"WS2","sub":"Al2O3","meth":"MOCVD","steps":10.0,"time":2.5,"temp":1000.0,"press":50.0,"rough":null,"hrange":null,"scan":null,"pix":null,"lines":null,"date":"2019-12-10","doi":"10.26207/f7b1-fs46"},{"id":17403,"label":"MCV1-191210D-HZ","mat":"WS2","sub":"Al2O3","meth":"MOCVD","steps":10.0,"time":10.0,"temp":1000.0,"press":50.0,"rough":null,"hrange":null,"scan":null,"pix":null,"lines":null,"date":"2019-12-10","doi":"10.26207/f7b1-fs46"},{"id":17404,"label":"MCV1-191122A-HZ","mat":"WS2","sub":"Al2O3","meth":"MOCVD","steps":10.0,"time":10.0,"temp":1000.0,"press":50.0,"rough":0.217,"hrange":9.96,"scan":2.0,"pix":512.0,"lines":512.0,"date":"2019-11-22","doi":"10.26207/f7b1-fs46"},{"id":17405,"label":"MCV1-191125A-HZ","mat":"WS2","sub":"Al2O3","meth":"MOCVD","steps":10.0,"time":12.0, ...

# %% [markdown]
# ## What each dial does to this dataset
#
# **Provenance, resolved to surfaced.** Resolved removes the rows whose material field holds a
# substrate name, merges spellings such as `MoS2; MoS2` into `MoS2`, and drops samples missing the
# numbers the question needs. Surfaced puts all of that back: 228 samples never had a growth time
# recorded and 106 were never measured.
#
# **Statistical, implicit to explicit.** Implicit keeps only the common 5 micrometre scan size and
# roughness under 10 nanometres, so the spread looks tame. Explicit keeps everything, including a
# sample that measured 92 nanometres and scans taken at other sizes, which are not fair to compare.
#
# **Structural, few to all.** Two columns, six, or all sixteen, including administrative fields
# that have nothing to do with the question.
#
# Note the line above the graph: it always says how many samples the graph could actually draw.
# With provenance surfaced, the table holds 1,005 rows but the graph draws 754, because the rest
# are missing one of the two values.

# %% [markdown]
# ## For a teacher
#
# A dial setting is a decision about what students meet first, not a change to the data. A picture
# graph class and a statistics class can work from the same records. The settings you would hand
# out differ; the crystals do not.
